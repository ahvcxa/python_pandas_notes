# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
print(df.mean(numeric_only=True)) # Avarage
# Out:
# No           75.500000
# Height        1.200000
# Weight       46.231333
# Legendary     0.026667
# dtype: float64

# %%
print(df["Height"].mean())
print(df["Height"].max())
print(df["Weight"].min())
# Out:
# 1.2
# 8.8
# 0.1

# %%
print(df.count())
# Out:
# No           150
# Name         150
# Type1        150
# Type2         67
# Height       150
# Weight       150
# Legendary    150
# dtype: int64

# %%
group = df.groupby("Type1")

# %%
print(group["Height"].sum())
# Out:
# Type1
# Bug         10.8
# Dragon       8.0
# Electric     7.7
# Fairy        1.9
# Fighting     8.3
# Fire        14.6
# Ghost        4.4
# Grass       13.0
# Ground       6.8
# Ice          3.1
# Normal      21.7
# Poison      17.1
# Psychic      9.6
# Rock        16.6
# Water       36.4
# Name: Height, dtype: float64

# %%
print(group["Height"].max())
# Out:
# Type1
# Bug         1.5
# Dragon      4.0
# Electric    1.6
# Fairy       1.3
# Fighting    1.6
# Fire        2.0
# Ghost       1.6
# Grass       2.0
# Ground      1.9
# Ice         1.7
# Normal      2.2
# Poison      3.5
# Psychic     2.0
# Rock        8.8
# Water       6.5
# Name: Height, dtype: float64

# %%
print(group["Legendary"].count())
# Out:
# Type1
# Bug         12
# Dragon       3
# Electric     9
# Fairy        2
# Fighting     7
# Fire        12
# Ghost        3
# Grass       12
# Ground       8
# Ice          2
# Normal      22
# Poison      14
# Psychic      7
# Rock         9
# Water       28
# Name: Legendary, dtype: int64
