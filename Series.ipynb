# %%
import pandas as pd

# %%
data = [100,102,103]
series = pd.Series(data, index= ["a","b","c"])

# %%
print(series)
# Out:
# a    100
# b    102
# c    103
# dtype: int64

# %%
print(series.loc["b"]) # location
print(series.iloc[1]) # index location
# Out:
# 102
# 102

# %%
pizzas = {'Mixed': 1930,'Vegan': 1330,'Three cheese': 1430,}

# %%
series = pd.Series(pizzas)

# %%
print(series) # First type Second Calories
# Out:
# Mixed           1930
# Vegan           1330
# Three cheese    1430
# dtype: int64

# %%
print(series[series<=1500]) # Show  1500 cal Pizzas or less
# Out:
# Vegan           1330
# Three cheese    1430
# dtype: int64
